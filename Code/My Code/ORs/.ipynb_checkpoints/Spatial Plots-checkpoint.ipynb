# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
from __future__ import print_function
from scipy.integrate import simps
from numpy import trapz
import math

def truncate(n, decimals=0):
    multiplier = 10 ** decimals
    return int(n * multiplier) / multiplier

# %%
HMC1 = pd.read_csv('HMC Expirement 1.csv')
HMC1 = HMC1.drop(range(0,50))

HMC2 = pd.read_csv('HMC Expirement 2.csv')
HMC2 = HMC2.drop(range(0,45))

HMC3 = pd.read_csv('HMC Expirement 3.csv')
HMC3 = HMC3.drop(range(0,30))

OR5B = pd.read_csv('OR 5 Blocked.csv')
OR5B = OR5B.drop(range(0,50))

OR5UB = pd.read_csv('OR 5 Unblocked.csv')
OR5UB = OR5UB.drop(range(0,50))

OR12B = pd.read_csv('OR 12 Blocked.csv')
OR12B = OR12B.drop(range(0,60))

OR12UB = pd.read_csv('OR 12 Unblocked.csv')
OR12UB = OR12UB.drop(range(0,60))

OR7B = pd.read_csv('OR7 Blocked.csv')
OR7B = OR7B.drop(range(0,60))

OR7UB = pd.read_csv('OR7 Unblocked.csv')
OR7UB = OR7UB.drop(range(0,60))

OR16B1 = pd.read_csv('OR16 Blocked 1.csv')
OR16B1 = OR16B1.drop(range(0,50))

OR16B2 = pd.read_csv('OR16 Blocked 2.csv')
OR16B2 = OR16B2.drop(range(0,40))

OR16UB = pd.read_csv('OR16 Unblocked.csv')
OR16UB = OR16UB.drop(range(0,37))

# %%
HMC1.head()
# Out:
#     B-01  B-02  B-04  B-05  B-06  B-07  B-08  B-09  B-10  B-11  ...  B-19  \
# 50  11.0   0.0   0.0   4.5   0.0   0.0   0.0  0.00   0.0   0.0  ...   0.0
# 51   9.9   0.0   0.0   4.5   0.0   0.0   0.0  0.45   2.7   0.0  ...   0.0
# 52   8.8   0.0   0.0   4.5   0.0   0.0   0.0  0.90   5.4   0.0  ...   0.0
# 53   7.7   0.0   0.0   4.5   0.0   0.0   0.0  1.35   8.1   0.0  ...   0.0
# 54   6.6   0.0   0.0   4.5   0.0   0.0   0.0  1.80  10.8   0.0  ...   0.0
#
#     B-20  B-21  B-22  B-23   Average     Variance    Zone 1  Zone 2  Zone 3
# 50   0.0   0.0   0.0  4.50  7.659091  1135.720041  1.428571   29.70     0.0
# 51   0.0   0.0   0.0  4.05  7.743182  1142.244731  1.542857   29.75     0.0
# 52   0.0   0.0   0.0  3.60  7.827273  1148.769421  1.657143   29.80     0.0
# 53   0.0   0.0   0.0  3.15  7.911364  1155.294112  1.771429   29.85     0.0
# 54   0.0   0.0   0.0  2.70  7.995455  1161.818802  1.885714   29.90     0.0
#
# [5 rows x 27 columns]

# %%
## Only run this cell once
HMC1.insert(0, "Time", np.arange(0, 481, 1), True)

HMC2.insert(0, "Time", np.arange(0, 486, 1), True)

HMC3.insert(0, "Time", np.arange(0, 861, 1), True)

OR5B.insert(0, "Time", np.arange(0, 301, 1), True)

OR5UB.insert(0, "Time", np.arange(0, 301, 1), True)

OR12B.insert(0, "Time", np.arange(0, 411, 1), True)

OR12UB.insert(0, "Time", np.arange(0, 471, 1), True)

OR7B.insert(0, "Time", np.arange(0, 291, 1), True)

OR7UB.insert(0, "Time", np.arange(0, 291, 1), True)

OR16B1.insert(0, "Time", np.arange(0, 301, 1), True)

OR16B2.insert(0, "Time", np.arange(0, 311, 1), True)

OR16UB.insert(0, "Time", np.arange(0, 314, 1), True)

# %% [markdown]
# ## For 3 Zones

# %%
HMC1['Zone 1'] = HMC1[['B-01', 'B-02', 'B-04', 'B-05', 'B-06', 'B-07', 'B-09', 'B-10', 'B-11', 'B-14', 'B-16', 'B-20', 'B-22', 'B-23']].mean(axis=1)
HMC1['Zone 2'] = HMC1[['B-08', 'B-12', 'B-13', 'B-15', 'B-19']].mean(axis=1)
HMC1['Zone 3'] = HMC1[['B-17', 'B-18', 'B-21']].mean(axis=1)
HMC1['Indoor Average'] = HMC1[['B-01', 'B-02', 'B-04', 'B-05', 'B-06', 'B-07', 'B-09', 'B-10', 'B-11', 'B-14', 'B-16', 'B-20', 'B-22', 'B-23', 'B-08', 'B-12', 'B-13', 'B-15', 'B-19', 'B-17', 'B-18', 'B-21']].mean(axis=1)


HMC2['Zone 1'] = HMC2[['B-01', 'B-02', 'B-04', 'B-05', 'B-06', 'B-07', 'B-10', 'B-11', 'B-13', 'B-14', 'B-20', 'B-23']].mean(axis=1)
HMC2['Zone 2'] = HMC2[['B-08', 'B-15', 'B-18', 'B-22']].mean(axis=1)
HMC2['Zone 3'] = HMC2[['B-09', 'B-12', 'B-16', 'B-17', 'B-19', 'B-21']].mean(axis=1)
HMC2['Indoor Average'] = HMC2[['B-01', 'B-02', 'B-04', 'B-05', 'B-06', 'B-07', 'B-09', 'B-10', 'B-11', 'B-14', 'B-16', 'B-20', 'B-22', 'B-23', 'B-08', 'B-12', 'B-13', 'B-15', 'B-19', 'B-17', 'B-18', 'B-21']].mean(axis=1)


HMC3['Zone 1'] = HMC3[['B-01', 'B-05', 'B-07', 'B-10', 'B-11', 'B-15']].mean(axis=1)
HMC3['Zone 2'] = HMC3[['B-02', 'B-04', 'B-06', 'B-08', 'B-09', 'B-13', 'B-15', 'B-18', 'B-20', 'B-23']].mean(axis=1)
HMC3['Zone 3'] = HMC3[['B-12', 'B-16', 'B-17', 'B-19', 'B-21', 'B-22']].mean(axis=1)
HMC3['Indoor Average'] = HMC3[['B-01', 'B-02', 'B-04', 'B-05', 'B-06', 'B-07', 'B-09', 'B-10', 'B-11', 'B-14', 'B-16', 'B-20', 'B-22', 'B-23', 'B-08', 'B-12', 'B-13', 'B-15', 'B-19', 'B-17', 'B-18', 'B-21']].mean(axis=1)


OR5B['Zone 1'] = OR5B[['S-01', 'S-02', 'S-03', 'S-04', 'S-05', 'S-06']].mean(axis=1)
OR5B['Zone 2'] = OR5B[['S-07', 'S-08', 'S-11', 'S-12', 'S-13', 'S-14', 'S-09', 'S-10']].mean(axis=1)
OR5B['Zone 3'] = OR5B[['S-15', 'S-18', 'S-19']].mean(axis=1)
OR5B['Indoor Average'] = OR5B[['S-01', 'S-02', 'S-04', 'S-05', 'S-06', 'S-07', 'S-08', 'S-11', 'S-12', 'S-13', 'S-14', 'S-03', 'S-09', 'S-10']].mean(axis=1)


OR5UB['Zone 1'] = OR5UB[['S-01', 'S-02', 'S-03', 'S-04', 'S-05', 'S-06']].mean(axis=1)
OR5UB['Zone 2'] = OR5UB[['S-07', 'S-08', 'S-11', 'S-12', 'S-13', 'S-14', 'S-09', 'S-10']].mean(axis=1)
OR5UB['Zone 3'] = OR5UB[['S-15', 'S-18', 'S-19']].mean(axis=1)
OR5UB['Indoor Average'] = OR5UB[['S-01', 'S-02', 'S-04', 'S-05', 'S-06', 'S-07', 'S-08', 'S-11', 'S-12', 'S-13', 'S-14', 'S-03', 'S-09', 'S-10']].mean(axis=1)


OR12B['Zone 1'] = OR12B[['S-01', 'S-02', 'S-03', 'S-04', 'S-05', 'S-06']].mean(axis=1)
OR12B['Zone 2'] = OR12B[['S-07', 'S-08', 'S-11', 'S-12', 'S-13', 'S-14', 'S-09', 'S-10']].mean(axis=1)
OR12B['Zone 3'] = OR12B[['S-15', 'S-18', 'S-19']].mean(axis=1)
OR12B['Indoor Average'] = OR12B[['S-01', 'S-02', 'S-04', 'S-05', 'S-06', 'S-07', 'S-08', 'S-11', 'S-12', 'S-13', 'S-14', 'S-03', 'S-09', 'S-10']].mean(axis=1)


OR12UB['Zone 1'] = OR12UB[['S-01', 'S-02', 'S-03', 'S-04', 'S-05', 'S-06']].mean(axis=1)
OR12UB['Zone 2'] = OR12UB[['S-07', 'S-08', 'S-11', 'S-12', 'S-13', 'S-14', 'S-09', 'S-10']].mean(axis=1)
OR12UB['Zone 3'] = OR12UB[['S-15', 'S-18', 'S-19']].mean(axis=1)
OR12UB['Indoor Average'] = OR12UB[['S-01', 'S-02', 'S-04', 'S-05', 'S-06', 'S-07', 'S-08', 'S-11', 'S-12', 'S-13', 'S-14', 'S-03', 'S-09', 'S-10']].mean(axis=1)


OR7B['Zone 1'] = OR7B[['S-09', 'S-12', 'S-13', 'S-14', 'S-11']].mean(axis=1)
OR7B['Zone 2'] = OR7B[['S-01', 'S-03', 'S-04', 'S-05', 'S-06', 'S-07', 'S-08', 'S-15']].mean(axis=1)
OR7B['Zone 3'] = OR7B[['S-BU1']].mean(axis=1)
OR7B['Indoor Average'] = OR7B[['S-01', 'S-03', 'S-04', 'S-05', 'S-06', 'S-07', 'S-09', 'S-11', 'S-12', 'S-13', 'S-14', 'S-15']].mean(axis=1)


OR7UB['Zone 1'] = OR7UB[['S-09', 'S-12', 'S-13', 'S-14', 'S-11']].mean(axis=1)
OR7UB['Zone 2'] = OR7UB[['S-01', 'S-03', 'S-04', 'S-05', 'S-06', 'S-07', 'S-08', 'S-15']].mean(axis=1)
OR7UB['Zone 3'] = OR7UB[['S-BU1']].mean(axis=1)
OR7UB['Indoor Average'] = OR7UB[['S-01', 'S-03', 'S-04', 'S-05', 'S-06', 'S-07', 'S-09', 'S-11', 'S-12', 'S-13', 'S-14', 'S-15']].mean(axis=1)


OR16B1['Zone 1'] = OR16B1[['S-09', 'S-12', 'S-13', 'S-14', 'S-11']].mean(axis=1)
OR16B1['Zone 2'] = OR16B1[['S-01', 'S-03', 'S-04', 'S-05', 'S-06', 'S-07', 'S-08', 'S-15']].mean(axis=1)
OR16B1['Zone 3'] = OR16B1[['S-BU1']].mean(axis=1)
OR16B1['Indoor Average'] = OR16B1[['S-01', 'S-03', 'S-04', 'S-05', 'S-06', 'S-07', 'S-09', 'S-11', 'S-12', 'S-13', 'S-14', 'S-15']].mean(axis=1)


OR16B2['Zone 1'] = OR16B2[['S-09', 'S-12', 'S-13', 'S-14', 'S-11']].mean(axis=1)
OR16B2['Zone 2'] = OR16B2[['S-01', 'S-03', 'S-04', 'S-05', 'S-06', 'S-07', 'S-08', 'S-15']].mean(axis=1)
OR16B2['Zone 3'] = OR16B2[['S-BU1']].mean(axis=1)
OR16B2['Indoor Average'] = OR16B2[['S-01', 'S-03', 'S-04', 'S-05', 'S-06', 'S-07', 'S-09', 'S-11', 'S-12', 'S-13', 'S-14', 'S-15']].mean(axis=1)


OR16UB['Zone 1'] = OR16UB[['S-09', 'S-12', 'S-13', 'S-14', 'S-11']].mean(axis=1)
OR16UB['Zone 2'] = OR16UB[['S-01', 'S-03', 'S-04', 'S-05', 'S-06', 'S-07', 'S-08', 'S-15']].mean(axis=1)
OR16UB['Zone 3'] = OR16UB[['S-BU1']].mean(axis=1)
OR16UB['Indoor Average'] = OR16UB[['S-01', 'S-03', 'S-04', 'S-05', 'S-06', 'S-07', 'S-09', 'S-11', 'S-12', 'S-13', 'S-14', 'S-15']].mean(axis=1)

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(HMC1['Time'], HMC1['Zone 1']/(100*10), linewidth=5.0)
plt.semilogy(HMC1['Time'], HMC1['Zone 2']/(100*10), linewidth=5.0)
plt.semilogy(HMC1['Time'], HMC1['Zone 3']/(100*10), linewidth=5.0)
plt.title('HMC Exp 1').set_size(30)
plt.xlabel('Time (s)').set_size(30)
plt.ylabel('Particle Concentration').set_size(30)
axes = plt.gca()
plt.ylim([0.001, 1.1])
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.axhline(y=0.0015, color='black', linestyle='--', linewidth=5.0)
plt.legend(['Zone 1', 'Zone 2', 'Zone 3', 'Background'], prop = {'size':20})

# # Compute the area using the composite Simpson's rule.
# Zone_1 = simps(HMC1['Zone 1']/(100*110) - 0.0065, dx=0.01)
# #print("area 1 =", area_1)

# Zone_2 = simps(HMC1['Zone 2']/(100*110) - 0.0065, dx=0.01)
# #print("area 2 =", area_2)

# Zone_3 = simps(HMC1['Zone 3']/(100*110) - 0.0065, dx=0.01)
# #print("area 3 =", area_3)




# inside = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14'])/(100*110))/13 - 0.0065, dx=0.01)
# #print("Inside =", inside)

# door_sensors = simps(((DO1_Alt['S-15']+DO1_Alt['S-18']+DO1_Alt['S-19'])/3)/(100*110) - 0.0065, dx=0.01)
# #print("Door Sensors =", door_sensors)

# nurses_station = simps(DO1_Alt['S-16']/(100*110) - 0.0065, dx=0.01)
# #print("Nurse's Station =", nurses_station)

# total_average = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14']+DO1_Alt['S-15']+DO1_Alt['S-16']+DO1_Alt['S-18']+DO1_Alt['S-19'])/(100*110))/17 - 0.0065, dx=0.01)
# #print("Total Average =", total_average)

# print("Inside =", inside/total_average)
# print("Door Sensors =", door_sensors/total_average)
# print("Nurse's Station =", nurses_station/total_average)
# print("Outside =", Zone_3/total_average)

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(HMC1['Time'], HMC1['Indoor Average']/(100*10), linewidth = 5, color='gray', linestyle = '-')
plt.title('HMC Exp 1').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.003, 1])

log_y_data = np.log(HMC1['Indoor Average']/(100*10))

time = HMC1['Time'][60:200]
y_data = log_y_data[60:200]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.0065, color='black', linestyle='--', linewidth=5.0)

text = ('ln(DR) =' + t_text + 't' + ' + ' +  'ln(' + yd_text + ')')

plt.text(200, 0.075, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.01860793 -0.04415956]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(HMC2['Time'], HMC2['Zone 1']/(100*20), linewidth=5.0)
plt.semilogy(HMC2['Time'], HMC2['Zone 2']/(100*20), linewidth=5.0)
plt.semilogy(HMC2['Time'], HMC2['Zone 3']/(100*20), linewidth=5.0)
plt.title('HMC Exp 2').set_size(30)
plt.xlabel('Time (s)').set_size(30)
plt.ylabel('Particle Concentration').set_size(30)
axes = plt.gca()
plt.ylim([0.0001, 1.1])
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.axhline(y=0.001, color='black', linestyle='--', linewidth=5.0)
plt.legend(['Zone 1', 'Zone 2', 'Zone 3', 'Background'], prop = {'size':20})

# # Compute the area using the composite Simpson's rule.
# Zone_1 = simps(HMC1['Zone 1']/(100*110) - 0.0065, dx=0.01)
# #print("area 1 =", area_1)

# Zone_2 = simps(HMC1['Zone 2']/(100*110) - 0.0065, dx=0.01)
# #print("area 2 =", area_2)

# Zone_3 = simps(HMC1['Zone 3']/(100*110) - 0.0065, dx=0.01)
# #print("area 3 =", area_3)




# inside = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14'])/(100*110))/13 - 0.0065, dx=0.01)
# #print("Inside =", inside)

# door_sensors = simps(((DO1_Alt['S-15']+DO1_Alt['S-18']+DO1_Alt['S-19'])/3)/(100*110) - 0.0065, dx=0.01)
# #print("Door Sensors =", door_sensors)

# nurses_station = simps(DO1_Alt['S-16']/(100*110) - 0.0065, dx=0.01)
# #print("Nurse's Station =", nurses_station)

# total_average = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14']+DO1_Alt['S-15']+DO1_Alt['S-16']+DO1_Alt['S-18']+DO1_Alt['S-19'])/(100*110))/17 - 0.0065, dx=0.01)
# #print("Total Average =", total_average)

# print("Inside =", inside/total_average)
# print("Door Sensors =", door_sensors/total_average)
# print("Nurse's Station =", nurses_station/total_average)
# print("Outside =", Zone_3/total_average)

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(HMC2['Time'], HMC2['Indoor Average']/(100*10), linewidth = 5, color='gray', linestyle = '-')
plt.title('HMC Exp 2').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.003, 1])

log_y_data = np.log(HMC2['Indoor Average']/(100*10))

time = HMC2['Time'][120:300]
y_data = log_y_data[120:300]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.0065, color='black', linestyle='--', linewidth=5.0)

text = ('ln(DR) =' + t_text + 't' + ' + ' +  'ln(' + yd_text + ')')

plt.text(250, 0.075, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.00839825 -2.12402659]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(HMC3['Time'], HMC3['Zone 1']/(100*55), linewidth=5.0)
plt.semilogy(HMC3['Time'], HMC3['Zone 2']/(100*55), linewidth=5.0)
plt.semilogy(HMC3['Time'], HMC3['Zone 3']/(100*55), linewidth=5.0)
plt.title('HMC Exp 3').set_size(30)
plt.xlabel('Time (s)').set_size(30)
plt.ylabel('Particle Concentration').set_size(30)
axes = plt.gca()
plt.ylim([0.0001, 1.1])
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.axhline(y=0.00055, color='black', linestyle='--', linewidth=5.0)
plt.legend(['Zone 1', 'Zone 2', 'Zone 3', 'Background'], prop = {'size':20})

# # Compute the area using the composite Simpson's rule.
# Zone_1 = simps(HMC1['Zone 1']/(100*110) - 0.0065, dx=0.01)
# #print("area 1 =", area_1)

# Zone_2 = simps(HMC1['Zone 2']/(100*110) - 0.0065, dx=0.01)
# #print("area 2 =", area_2)

# Zone_3 = simps(HMC1['Zone 3']/(100*110) - 0.0065, dx=0.01)
# #print("area 3 =", area_3)




# inside = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14'])/(100*110))/13 - 0.0065, dx=0.01)
# #print("Inside =", inside)

# door_sensors = simps(((DO1_Alt['S-15']+DO1_Alt['S-18']+DO1_Alt['S-19'])/3)/(100*110) - 0.0065, dx=0.01)
# #print("Door Sensors =", door_sensors)

# nurses_station = simps(DO1_Alt['S-16']/(100*110) - 0.0065, dx=0.01)
# #print("Nurse's Station =", nurses_station)

# total_average = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14']+DO1_Alt['S-15']+DO1_Alt['S-16']+DO1_Alt['S-18']+DO1_Alt['S-19'])/(100*110))/17 - 0.0065, dx=0.01)
# #print("Total Average =", total_average)

# print("Inside =", inside/total_average)
# print("Door Sensors =", door_sensors/total_average)
# print("Nurse's Station =", nurses_station/total_average)
# print("Outside =", Zone_3/total_average)

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(HMC3['Time'], HMC3['Indoor Average']/(100*55), linewidth = 5, color='gray', linestyle = '-')
plt.title('HMC Exp 3').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.003, 1])

log_y_data = np.log(HMC3['Indoor Average']/(100*55))

time = HMC3['Time'][400:600]
y_data = log_y_data[400:600]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.0065, color='black', linestyle='--', linewidth=5.0)

text = ('ln(DR) =' + t_text + 't' + ' + ' +  'ln(' + yd_text + ')')

plt.text(250, 0.075, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.00779878 -0.21194294]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR5B['Time'], OR5B['Zone 1']/(100*11), linewidth=5.0)
plt.semilogy(OR5B['Time'], OR5B['Zone 2']/(100*11), linewidth=5.0)
plt.semilogy(OR5B['Time'], OR5B['Zone 3']/(100*11), linewidth=5.0)
plt.title('OR 5 Blocked').set_size(30)
plt.xlabel('Time (s)').set_size(30)
plt.ylabel('Particle Concentration').set_size(30)
axes = plt.gca()
plt.ylim([0.08, 1.1])
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.axhline(y=0.15, color='black', linestyle='--', linewidth=5.0)
plt.legend(['Zone 1', 'Zone 2', 'Zone 3', 'Background'], prop = {'size':20})

# # Compute the area using the composite Simpson's rule.
# Zone_1 = simps(HMC1['Zone 1']/(100*110) - 0.0065, dx=0.01)
# #print("area 1 =", area_1)

# Zone_2 = simps(HMC1['Zone 2']/(100*110) - 0.0065, dx=0.01)
# #print("area 2 =", area_2)

# Zone_3 = simps(HMC1['Zone 3']/(100*110) - 0.0065, dx=0.01)
# #print("area 3 =", area_3)




# inside = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14'])/(100*110))/13 - 0.0065, dx=0.01)
# #print("Inside =", inside)

# door_sensors = simps(((DO1_Alt['S-15']+DO1_Alt['S-18']+DO1_Alt['S-19'])/3)/(100*110) - 0.0065, dx=0.01)
# #print("Door Sensors =", door_sensors)

# nurses_station = simps(DO1_Alt['S-16']/(100*110) - 0.0065, dx=0.01)
# #print("Nurse's Station =", nurses_station)

# total_average = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14']+DO1_Alt['S-15']+DO1_Alt['S-16']+DO1_Alt['S-18']+DO1_Alt['S-19'])/(100*110))/17 - 0.0065, dx=0.01)
# #print("Total Average =", total_average)

# print("Inside =", inside/total_average)
# print("Door Sensors =", door_sensors/total_average)
# print("Nurse's Station =", nurses_station/total_average)
# print("Outside =", Zone_3/total_average)

OR5B.head()
# Out:
#     Time   S-01  S-02   S-03  S-04   S-05   S-06        S-07        S-08  \
# 50     0   83.0  87.0  117.0  44.0   79.0  112.0  160.333333  209.333333
# 51     1   88.0  89.9  113.1  44.7  156.0  112.1  159.000000  208.300000
# 52     2   93.0  92.8  109.2  45.4  233.0  112.2  157.666667  207.266667
# 53     3   98.0  95.7  105.3  46.1  310.0  112.3  156.333333  206.233333
# 54     4  103.0  98.6  101.4  46.8  387.0  112.4  155.000000  205.200000
#
#           S-09  ...   S-15  S-16  S-18  S-19    Average      Variance  \
# 50  363.333333  ...  129.0  48.0  87.0  64.0  123.97619  12108.960884
# 51  360.800000  ...  128.6  48.0  88.0  62.3  129.37619  17647.224830
# 52  358.266667  ...  128.2  48.0  89.0  60.6  134.77619  23185.488776
# 53  355.733333  ...  127.8  48.0  90.0  58.9  140.17619  28723.752721
# 54  353.200000  ...  127.4  48.0  91.0  57.2  145.57619  34262.016667
#
#         Zone 1      Zone 2     Zone 3  Indoor Average
# 50   87.000000  151.708333  93.333333       123.97619
# 51  100.633333  150.933333  92.966667       129.37619
# 52  114.266667  150.158333  92.600000       134.77619
# 53  127.900000  149.383333  92.233333       140.17619
# 54  141.533333  148.608333  91.866667       145.57619
#
# [5 rows x 25 columns]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
OR5B_r = OR5B.drop(range(50,119))
t0 = 70
time = OR5B_r['Time'] - t0
plt.semilogy(time, OR5B_r['Indoor Average']/(100*11), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 5 Blocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.1, 1])

log_y_data = np.log(OR5B_r['Indoor Average']/(100*11))

time = time[0:80]
y_data = log_y_data[0:80]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.17, color='black', linestyle='--', linewidth=5.0)

text = ('ln(DR) =' + t_text + 't' + ' + ' +  'ln(' + yd_text + ')')

plt.text(50, 0.3, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.01773261 -0.74850972]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR5B['Time'], OR5B['Indoor Average']/(100*11), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 5 Blocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.1, 1])

log_y_data = np.log(OR5B['Indoor Average']/(100*11))

time = OR5B['Time'][70:150]
y_data = log_y_data[70:150]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.17, color='black', linestyle='--', linewidth=5.0)
plt.axhline(y=0.473, color='black', linestyle='--', linewidth=2.0)

text = ('ln(DR) = - 0.0177(t - t0) + ln(0.473)')

plt.text(120, 0.3, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.01748884  0.46647301]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR5UB['Time'], OR5UB['Zone 1']/(100*40), linewidth=5.0)
plt.semilogy(OR5UB['Time'], OR5UB['Zone 2']/(100*40), linewidth=5.0)
plt.semilogy(OR5UB['Time'], OR5UB['Zone 3']/(100*40), linewidth=5.0)
plt.title('OR 5 Unblocked').set_size(30)
plt.xlabel('Time (s)').set_size(30)
plt.ylabel('Particle Concentration').set_size(30)
axes = plt.gca()
plt.ylim([0.03, 1.1])
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.axhline(y=0.05, color='black', linestyle='--', linewidth=5.0)
plt.legend(['Zone 1', 'Zone 2', 'Zone 3', 'Background'], prop = {'size':20})

# # Compute the area using the composite Simpson's rule.
# Zone_1 = simps(HMC1['Zone 1']/(100*110) - 0.0065, dx=0.01)
# #print("area 1 =", area_1)

# Zone_2 = simps(HMC1['Zone 2']/(100*110) - 0.0065, dx=0.01)
# #print("area 2 =", area_2)

# Zone_3 = simps(HMC1['Zone 3']/(100*110) - 0.0065, dx=0.01)
# #print("area 3 =", area_3)




# inside = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14'])/(100*110))/13 - 0.0065, dx=0.01)
# #print("Inside =", inside)

# door_sensors = simps(((DO1_Alt['S-15']+DO1_Alt['S-18']+DO1_Alt['S-19'])/3)/(100*110) - 0.0065, dx=0.01)
# #print("Door Sensors =", door_sensors)

# nurses_station = simps(DO1_Alt['S-16']/(100*110) - 0.0065, dx=0.01)
# #print("Nurse's Station =", nurses_station)

# total_average = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14']+DO1_Alt['S-15']+DO1_Alt['S-16']+DO1_Alt['S-18']+DO1_Alt['S-19'])/(100*110))/17 - 0.0065, dx=0.01)
# #print("Total Average =", total_average)

# print("Inside =", inside/total_average)
# print("Door Sensors =", door_sensors/total_average)
# print("Nurse's Station =", nurses_station/total_average)
# print("Outside =", Zone_3/total_average)
OR5UB.head()
# Out:
#     Time    S-01  S-02   S-03  S-04    S-05   S-06    S-07   S-08    S-09  \
# 50     0   90.50  79.5   97.5  43.5   82.00  86.50  118.50  117.5  299.50
# 51     1  217.35  82.7   99.6  45.4  280.25  82.95  117.75  117.9  302.95
# 52     2  344.20  85.9  101.7  47.3  478.50  79.40  117.00  118.3  306.40
# 53     3  471.05  89.1  103.8  49.2  676.75  75.85  116.25  118.7  309.85
# 54     4  597.90  92.3  105.9  51.1  875.00  72.30  115.50  119.1  313.30
#
#     ...    S-15   S-16    S-18   S-19     Average       Variance      Zone 1  \
# 50  ...  128.50  62.50   98.50  70.00  105.821429    6263.084184   79.916667
# 51  ...  134.85  63.25  101.75  69.45  129.527381  156222.990731  134.708333
# 52  ...  141.20  64.00  105.00  68.90  153.233333  306182.897279  189.500000
# 53  ...  147.55  64.75  108.25  68.35  176.939286  456142.803827  244.291667
# 54  ...  153.90  65.50  111.50  67.80  200.645238  606102.710374  299.083333
#
#         Zone 2      Zone 3  Indoor Average
# 50  125.250000   99.000000      105.821429
# 51  125.641667  102.016667      129.527381
# 52  126.033333  105.033333      153.233333
# 53  126.425000  108.050000      176.939286
# 54  126.816667  111.066667      200.645238
#
# [5 rows x 25 columns]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
OR5UB_r = OR5UB.drop(range(50,79))
t0 = 30
time = OR5UB_r['Time'] - t0
plt.semilogy(time, OR5UB_r['Indoor Average']/(100*40), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 5 Unblocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.04, 1])

log_y_data = np.log(OR5UB_r['Indoor Average']/(100*40))

time = time[0:150]
y_data = log_y_data[0:150]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.17, color='black', linestyle='--', linewidth=5.0)

text = ('ln(DR) =' + t_text + 't' + ' + ' +  'ln(' + yd_text + ')')

plt.text(50, 0.3, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.01665614 -0.98141439]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR5UB['Time'], OR5UB['Indoor Average']/(100*40), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 5 Unblocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.04, 1])

log_y_data = np.log(OR5UB['Indoor Average']/(100*40))

time = OR5UB['Time'][30:180]
y_data = log_y_data[30:180]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.05, color='black', linestyle='--', linewidth=5.0)
plt.axhline(y=0.374, color='black', linestyle='--', linewidth=2.0)

text = ('ln(DR) = -0.0166(t - t0) + ln(0.374)')

plt.text(110, 0.2, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.01656581 -0.49054159]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR12B['Time'], OR12B['Zone 1']/(100*47), linewidth=5.0)
plt.semilogy(OR12B['Time'], OR12B['Zone 2']/(100*47), linewidth=5.0)
plt.semilogy(OR12B['Time'], OR12B['Zone 3']/(100*47), linewidth=5.0)
plt.title('OR 12 Blocked').set_size(30)
plt.xlabel('Time (s)').set_size(30)
plt.ylabel('Particle Concentration').set_size(30)
axes = plt.gca()
plt.ylim([0.009, 1.1])
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.axhline(y=0.02, color='black', linestyle='--', linewidth=5.0)
plt.legend(['Zone 1', 'Zone 2', 'Zone 3', 'Background'], prop = {'size':20})

# # Compute the area using the composite Simpson's rule.
# Zone_1 = simps(HMC1['Zone 1']/(100*110) - 0.0065, dx=0.01)
# #print("area 1 =", area_1)

# Zone_2 = simps(HMC1['Zone 2']/(100*110) - 0.0065, dx=0.01)
# #print("area 2 =", area_2)

# Zone_3 = simps(HMC1['Zone 3']/(100*110) - 0.0065, dx=0.01)
# #print("area 3 =", area_3)




# inside = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14'])/(100*110))/13 - 0.0065, dx=0.01)
# #print("Inside =", inside)

# door_sensors = simps(((DO1_Alt['S-15']+DO1_Alt['S-18']+DO1_Alt['S-19'])/3)/(100*110) - 0.0065, dx=0.01)
# #print("Door Sensors =", door_sensors)

# nurses_station = simps(DO1_Alt['S-16']/(100*110) - 0.0065, dx=0.01)
# #print("Nurse's Station =", nurses_station)

# total_average = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14']+DO1_Alt['S-15']+DO1_Alt['S-16']+DO1_Alt['S-18']+DO1_Alt['S-19'])/(100*110))/17 - 0.0065, dx=0.01)
# #print("Total Average =", total_average)

# print("Inside =", inside/total_average)
# print("Door Sensors =", door_sensors/total_average)
# print("Nurse's Station =", nurses_station/total_average)
# print("Outside =", Zone_3/total_average)

OR12B.head()
# Out:
#     Time    S-01  S-02   S-03  S-04   S-05   S-06   S-07       S-08  \
# 60     0    53.0  73.0  141.0  70.0   54.0  102.0  120.0  89.333333
# 61     1  1818.2  74.5  135.9  69.0   84.4  100.3  119.7  89.000000
# 62     2  3583.4  76.0  130.8  68.0  114.8   98.6  119.4  88.666667
# 63     3  5348.6  77.5  125.7  67.0  145.2   96.9  119.1  88.333333
# 64     4  7113.8  79.0  120.6  66.0  175.6   95.2  118.8  88.000000
#
#           S-09  ...  S-15  S-16  S-18  S-19     Average      Variance  \
# 60  133.000000  ...  60.0  61.0  16.0  60.0   89.642857  2.235349e+03
# 61  133.833333  ...  57.4  61.6  18.3  58.8  217.550000  6.180787e+06
# 62  134.666667  ...  54.8  62.2  20.6  57.6  345.457143  1.235934e+07
# 63  135.500000  ...  52.2  62.8  22.9  56.4  473.364286  1.853789e+07
# 64  136.333333  ...  49.6  63.4  25.2  55.2  601.271429  2.471644e+07
#
#          Zone 1  Zone 2     Zone 3  Indoor Average
# 60    82.166667  95.250  45.333333       89.642857
# 61   380.383333  95.425  44.833333      217.550000
# 62   678.600000  95.600  44.333333      345.457143
# 63   976.816667  95.775  43.833333      473.364286
# 64  1275.033333  95.950  43.333333      601.271429
#
# [5 rows x 25 columns]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
OR12B_r = OR12B.drop(range(60,180))
t0 = 120
time = OR12B_r['Time'] - 120
plt.semilogy(time, OR12B_r['Indoor Average']/(100*47), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 12 Blocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.02, 1])

log_y_data = np.log(OR12B_r['Indoor Average']/(100*47))

time = time[0:230]
y_data = log_y_data[0:230]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.02, color='black', linestyle='--', linewidth=5.0)

text = ('ln(DR) =' + t_text + 't' + ' + ' +  'ln(' + yd_text + ')')

plt.text(50, 0.1, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.00487852 -2.76514812]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR12B['Time'], OR12B['Indoor Average']/(100*47), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 12 Blocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.02, 1])

log_y_data = np.log(OR12B['Indoor Average']/(100*47))

time = OR12UB['Time'][120:350]
y_data = log_y_data[120:350]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.02, color='black', linestyle='--', linewidth=5.0)
plt.axhline(y=0.062, color='black', linestyle='--', linewidth=2.0)

text = ('ln(DR) = -0.0048(t - t0) + ln(0.062)')

plt.text(180, 0.07, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.00487852 -2.17972623]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR12UB['Time'], OR12UB['Zone 1']/(100*67), linewidth=5.0)
plt.semilogy(OR12UB['Time'], OR12UB['Zone 2']/(100*67), linewidth=5.0)
plt.semilogy(OR12UB['Time'], OR12UB['Zone 3']/(100*67), linewidth=5.0)
plt.title('OR 12 Unblocked').set_size(30)
plt.xlabel('Time (s)').set_size(30)
plt.ylabel('Particle Concentration').set_size(30)
axes = plt.gca()
plt.ylim([0.009, 1.1])
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.axhline(y=0.024, color='black', linestyle='--', linewidth=5.0)
plt.legend(['Zone 1', 'Zone 2', 'Zone 3', 'Background'], prop = {'size':20})

# # Compute the area using the composite Simpson's rule.
# Zone_1 = simps(HMC1['Zone 1']/(100*110) - 0.0065, dx=0.01)
# #print("area 1 =", area_1)

# Zone_2 = simps(HMC1['Zone 2']/(100*110) - 0.0065, dx=0.01)
# #print("area 2 =", area_2)

# Zone_3 = simps(HMC1['Zone 3']/(100*110) - 0.0065, dx=0.01)
# #print("area 3 =", area_3)




# inside = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14'])/(100*110))/13 - 0.0065, dx=0.01)
# #print("Inside =", inside)

# door_sensors = simps(((DO1_Alt['S-15']+DO1_Alt['S-18']+DO1_Alt['S-19'])/3)/(100*110) - 0.0065, dx=0.01)
# #print("Door Sensors =", door_sensors)

# nurses_station = simps(DO1_Alt['S-16']/(100*110) - 0.0065, dx=0.01)
# #print("Nurse's Station =", nurses_station)

# total_average = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14']+DO1_Alt['S-15']+DO1_Alt['S-16']+DO1_Alt['S-18']+DO1_Alt['S-19'])/(100*110))/17 - 0.0065, dx=0.01)
# #print("Total Average =", total_average)

# print("Inside =", inside/total_average)
# print("Door Sensors =", door_sensors/total_average)
# print("Nurse's Station =", nurses_station/total_average)
# print("Outside =", Zone_3/total_average)

OR12UB.head()
# Out:
#     Time     S-01   S-02   S-03   S-04  S-05  S-06        S-07       S-08  \
# 60     0     97.0  109.0  122.0   95.0  79.0  72.0  109.333333  98.000000
# 61     1   3937.4  136.7  121.1   97.7  75.4  71.9  108.600000  97.966667
# 62     2   7777.8  164.4  120.2  100.4  71.8  71.8  107.866667  97.933333
# 63     3  11618.2  192.1  119.3  103.1  68.2  71.7  107.133333  97.900000
# 64     4  15458.6  219.8  118.4  105.8  64.6  71.6  106.400000  97.866667
#
#      S-09  ...  S-15  S-16  S-18  S-19      Average      Variance  \
# 60  106.0  ...  29.0  68.0  64.0  69.0   111.928571  4.281563e+03
# 61  106.1  ...  27.3  70.6  65.4  68.7   388.042857  1.288321e+07
# 62  106.2  ...  25.6  73.2  66.8  68.4   664.157143  2.576214e+07
# 63  106.3  ...  23.9  75.8  68.2  68.1   940.271429  3.864108e+07
# 64  106.4  ...  22.2  78.4  69.6  67.8  1216.385714  5.152001e+07
#
#          Zone 1   Zone 2  Zone 3  Indoor Average
# 60    95.666667  124.125    54.0      111.928571
# 61   740.033333  124.050    53.8      388.042857
# 62  1384.400000  123.975    53.6      664.157143
# 63  2028.766667  123.900    53.4      940.271429
# 64  2673.133333  123.825    53.2     1216.385714
#
# [5 rows x 25 columns]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
OR12UB_r = OR12UB.drop(range(60,159))
t0 = 100
time = OR12UB_r['Time'] - t0

plt.semilogy(time, OR12UB_r['Indoor Average']/(100*67), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 12 Unblocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.02, 1])

log_y_data = np.log(OR12UB_r['Indoor Average']/(100*67))

time = OR12UB['Time'][0:200]
y_data = log_y_data[0:200]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.03, color='black', linestyle='--', linewidth=5.0)

text = ('ln(DR) =' + t_text + 't' + ' + ' +  'ln(' + yd_text + ')')

plt.text(180, 0.2, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.00572513 -2.89162768]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR12UB['Time'], OR12UB['Indoor Average']/(100*67), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 12 Unblocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.02, 1])

log_y_data = np.log(OR12UB['Indoor Average']/(100*67))

time = OR12UB['Time'][100:300]
y_data = log_y_data[100:300]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.03, color='black', linestyle='--', linewidth=5.0)
plt.axhline(y=0.055, color='black', linestyle='--', linewidth=2.0)

text = ('ln(DR) = -0.0057(t - t0) + ln(0.055)')

plt.text(180, 0.04, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.00569526 -2.32963774]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR7B['Time'], OR7B['Zone 1']/(100*18), linewidth=5.0)
plt.semilogy(OR7B['Time'], OR7B['Zone 2']/(100*18), linewidth=5.0)
plt.semilogy(OR7B['Time'], OR7B['Zone 3']/(100*18), linewidth=5.0)
plt.title('OR 7 Blocked').set_size(30)
plt.xlabel('Time (s)').set_size(30)
plt.ylabel('Particle Concentration').set_size(30)
axes = plt.gca()
plt.ylim([0.008, 1.1])
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.axhline(y=0.01, color='black', linestyle='--', linewidth=5.0)
plt.legend(['Zone 1', 'Zone 2', 'Zone 3', 'Background'], prop = {'size':20})

# # Compute the area using the composite Simpson's rule.
# Zone_1 = simps(HMC1['Zone 1']/(100*110) - 0.0065, dx=0.01)
# #print("area 1 =", area_1)

# Zone_2 = simps(HMC1['Zone 2']/(100*110) - 0.0065, dx=0.01)
# #print("area 2 =", area_2)

# Zone_3 = simps(HMC1['Zone 3']/(100*110) - 0.0065, dx=0.01)
# #print("area 3 =", area_3)




# inside = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14'])/(100*110))/13 - 0.0065, dx=0.01)
# #print("Inside =", inside)

# door_sensors = simps(((DO1_Alt['S-15']+DO1_Alt['S-18']+DO1_Alt['S-19'])/3)/(100*110) - 0.0065, dx=0.01)
# #print("Door Sensors =", door_sensors)

# nurses_station = simps(DO1_Alt['S-16']/(100*110) - 0.0065, dx=0.01)
# #print("Nurse's Station =", nurses_station)

# total_average = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14']+DO1_Alt['S-15']+DO1_Alt['S-16']+DO1_Alt['S-18']+DO1_Alt['S-19'])/(100*110))/17 - 0.0065, dx=0.01)
# #print("Total Average =", total_average)

# print("Inside =", inside/total_average)
# print("Door Sensors =", door_sensors/total_average)
# print("Nurse's Station =", nurses_station/total_average)
# print("Outside =", Zone_3/total_average)
OR7B.head()
# Out:
#     Time  S-01      S-03  S-04  S-05  S-06  S-07  S-08  S-09  S-11  ...  S-14  \
# 60     0  30.0  9.000000  18.0   9.0  63.0   9.0   0.0  10.0  13.0  ...   9.0
# 61     1  28.3  8.533333  17.7   8.7  62.3   9.0   0.0   9.0  12.3  ...   8.7
# 62     2  26.6  8.066667  17.4   8.4  61.6   9.0   0.0   8.0  11.6  ...   8.4
# 63     3  24.9  7.600000  17.1   8.1  60.9   9.0   0.0   7.0  10.9  ...   8.1
# 64     4  23.2  7.133333  16.8   7.8  60.2   9.0   0.0   6.0  10.2  ...   7.8
#
#     S-15     S-BU1    Average    Variance  Zone 1     Zone 2    Zone 3  \
# 60  13.0  5.666667  14.769231  313.242604    8.20  18.875000  5.666667
# 61  12.7  6.133333  15.048718  403.704142    9.68  18.404167  6.133333
# 62  12.4  6.600000  15.328205  494.165680   11.16  17.933333  6.600000
# 63  12.1  7.066667  15.607692  584.627219   12.64  17.462500  7.066667
# 64  11.8  7.533333  15.887179  675.088757   14.12  16.991667  7.533333
#
#     Zone 4  Indoor Average
# 60     0.0       16.000000
# 61     0.0       16.302778
# 62     0.0       16.605556
# 63     0.0       16.908333
# 64     0.0       17.211111
#
# [5 rows x 22 columns]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
OR7B_r = OR7B.drop(range(60,159))
t0 = 100
time = OR7B_r['Time'] - t0

plt.semilogy(time, OR7B_r['Indoor Average']/(100*18), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 7 Blocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.02, 1])

log_y_data = np.log(OR7B_r['Indoor Average']/(100*18))

time = OR7B['Time'][0:120]
y_data = log_y_data[0:120]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.03, color='black', linestyle='--', linewidth=5.0)

text = ('ln(DR) =' + t_text + 't' + ' + ' +  'ln(' + yd_text + ')')

plt.text(50, 0.1, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.01259708 -2.31435535]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR7B['Time'], OR7B['Indoor Average']/(100*18), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 7 Blocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.02, 1])

log_y_data = np.log(OR7B['Indoor Average']/(100*18))

time = OR7B['Time'][100:220]
y_data = log_y_data[100:220]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.03, color='black', linestyle='--', linewidth=5.0)
plt.axhline(y=0.098, color='black', linestyle='--', linewidth=2.0)

text = ('ln(DR) = -0.0125(t - t0) + ln(0.098)')

plt.text(120, 0.12, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.01243546 -1.09777919]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR7UB['Time'], OR7UB['Zone 1']/(100*12), linewidth=5.0)
plt.semilogy(OR7UB['Time'], OR7UB['Zone 2']/(100*12), linewidth=5.0)
plt.semilogy(OR7UB['Time'], OR7UB['Zone 3']/(100*12), linewidth=5.0)
plt.title('OR 7 Unblocked').set_size(30)
plt.xlabel('Time (s)').set_size(30)
plt.ylabel('Particle Concentration').set_size(30)
axes = plt.gca()
plt.ylim([0.003, 1.1])
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.axhline(y=0.01, color='black', linestyle='--', linewidth=5.0)
plt.legend(['Zone 1', 'Zone 2', 'Zone 3', 'Background'], prop = {'size':20})

# # Compute the area using the composite Simpson's rule.
# Zone_1 = simps(HMC1['Zone 1']/(100*110) - 0.0065, dx=0.01)
# #print("area 1 =", area_1)

# Zone_2 = simps(HMC1['Zone 2']/(100*110) - 0.0065, dx=0.01)
# #print("area 2 =", area_2)

# Zone_3 = simps(HMC1['Zone 3']/(100*110) - 0.0065, dx=0.01)
# #print("area 3 =", area_3)




# inside = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14'])/(100*110))/13 - 0.0065, dx=0.01)
# #print("Inside =", inside)

# door_sensors = simps(((DO1_Alt['S-15']+DO1_Alt['S-18']+DO1_Alt['S-19'])/3)/(100*110) - 0.0065, dx=0.01)
# #print("Door Sensors =", door_sensors)

# nurses_station = simps(DO1_Alt['S-16']/(100*110) - 0.0065, dx=0.01)
# #print("Nurse's Station =", nurses_station)

# total_average = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14']+DO1_Alt['S-15']+DO1_Alt['S-16']+DO1_Alt['S-18']+DO1_Alt['S-19'])/(100*110))/17 - 0.0065, dx=0.01)
# #print("Total Average =", total_average)

# print("Inside =", inside/total_average)
# print("Door Sensors =", door_sensors/total_average)
# print("Nurse's Station =", nurses_station/total_average)
# print("Outside =", Zone_3/total_average)
OR7UB.head()
# Out:
#     Time  S-01  S-03       S-04  S-05       S-06       S-07  S-08   S-09  \
# 60     0  35.0   8.0  13.333333   3.0  57.333333  19.000000   0.0    3.0
# 61     1  33.8   7.5  12.900000   2.7  58.400000  18.133333   0.0   62.9
# 62     2  32.6   7.0  12.466667   2.4  59.466667  17.266667   0.0  122.8
# 63     3  31.4   6.5  12.033333   2.1  60.533333  16.400000   0.0  182.7
# 64     4  30.2   6.0  11.600000   1.8  61.600000  15.533333   0.0  242.6
#
#     S-11  ...   S-14  S-15  S-BU1    Average      Variance  Zone 1     Zone 2  \
# 60   6.0  ...   13.0  13.0   18.0  15.051282    450.698225    9.40  18.583333
# 61   6.3  ...   42.1  13.0   17.5  24.979487   8547.705325   35.66  18.304167
# 62   6.6  ...   71.2  13.0   17.0  34.907692  16644.712426   61.92  18.025000
# 63   6.9  ...  100.3  13.0   16.5  44.835897  24741.719527   88.18  17.745833
# 64   7.2  ...  129.4  13.0   16.0  54.764103  32838.726627  114.44  17.466667
#
#     Zone 3  Zone 4  Indoor Average
# 60    18.0     0.0       16.305556
# 61    17.5     0.0       27.061111
# 62    17.0     0.0       37.816667
# 63    16.5     0.0       48.572222
# 64    16.0     0.0       59.327778
#
# [5 rows x 22 columns]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
OR7UB_r = OR7UB.drop(range(60,139))
t0 = 80
time = OR7UB_r['Time'] - t0

plt.semilogy(time, OR7UB_r['Indoor Average']/(100*12), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 7 Unblocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.02, 1])

log_y_data = np.log(OR7UB_r['Indoor Average']/(100*12))

time = OR7UB['Time'][0:190]
y_data = log_y_data[0:190]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.03, color='black', linestyle='--', linewidth=5.0)

text = ('ln(DR) =' + t_text + 't' + ' + ' +  'ln(' + yd_text + ')')

plt.text(50, 0.1, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.00978336 -2.15538141]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR7UB['Time'], OR7UB['Indoor Average']/(100*12), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 7 Unblocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.02, 1])

log_y_data = np.log(OR7UB['Indoor Average']/(100*12))

time = OR7UB['Time'][80:270]
y_data = log_y_data[80:270]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.03, color='black', linestyle='--', linewidth=5.0)
plt.axhline(y=0.115, color='black', linestyle='--', linewidth=2.0)

text = ('ln(DR) = -0.0097(t - t0) + ln(0.115)')

plt.text(100, 0.15, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.0096804  -1.40121454]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR16UB['Time'], OR16UB['Zone 1']/(100*80), linewidth=5.0)
plt.semilogy(OR16UB['Time'], OR16UB['Zone 2']/(100*80), linewidth=5.0)
plt.semilogy(OR16UB['Time'], OR16UB['Zone 3']/(100*80), linewidth=5.0)
plt.title('OR 16 Unblocked').set_size(30)
plt.xlabel('Time (s)').set_size(30)
plt.ylabel('Particle Concentration').set_size(30)
axes = plt.gca()
plt.ylim([0.0003, 1.1])
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.axhline(y=0.002, color='black', linestyle='--', linewidth=5.0)
plt.legend(['Zone 1', 'Zone 2', 'Zone 3', 'Background'], prop = {'size':20})

# # Compute the area using the composite Simpson's rule.
# Zone_1 = simps(HMC1['Zone 1']/(100*110) - 0.0065, dx=0.01)
# #print("area 1 =", area_1)

# Zone_2 = simps(HMC1['Zone 2']/(100*110) - 0.0065, dx=0.01)
# #print("area 2 =", area_2)

# Zone_3 = simps(HMC1['Zone 3']/(100*110) - 0.0065, dx=0.01)
# #print("area 3 =", area_3)




# inside = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14'])/(100*110))/13 - 0.0065, dx=0.01)
# #print("Inside =", inside)

# door_sensors = simps(((DO1_Alt['S-15']+DO1_Alt['S-18']+DO1_Alt['S-19'])/3)/(100*110) - 0.0065, dx=0.01)
# #print("Door Sensors =", door_sensors)

# nurses_station = simps(DO1_Alt['S-16']/(100*110) - 0.0065, dx=0.01)
# #print("Nurse's Station =", nurses_station)

# total_average = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14']+DO1_Alt['S-15']+DO1_Alt['S-16']+DO1_Alt['S-18']+DO1_Alt['S-19'])/(100*110))/17 - 0.0065, dx=0.01)
# #print("Total Average =", total_average)

# print("Inside =", inside/total_average)
# print("Door Sensors =", door_sensors/total_average)
# print("Nurse's Station =", nurses_station/total_average)
# print("Outside =", Zone_3/total_average)
OR16UB.head()
# Out:
#     Time      S-01      S-03  S-04      S-05      S-06  S-07  S-08  S-09  \
# 37     0  6.700000  5.733333   0.0  1.300000  0.000000   3.9   0.0  21.1
# 38     1  6.466667  4.266667   0.0  0.866667  0.000000   3.6   0.0  21.4
# 39     2  6.233333  2.800000   0.0  0.433333  0.000000   3.3   0.0  21.7
# 40     3  6.000000  1.333333   0.0  0.000000  0.000000   3.0   0.0  22.0
# 41     4  6.000000  1.200000   0.0  0.000000  0.533333   2.7   0.0  20.1
#
#     S-11  ...  S-14  S-15     S-BU1    Average     Variance  Zone 1    Zone 2  \
# 37   0.0  ...   9.8   7.9  7.866667  14.717949  3803.355030   33.16  3.191667
# 38   0.0  ...  11.2   7.6  7.800000  14.461538  3688.946746   33.04  2.850000
# 39   0.0  ...  12.6   7.3  7.733333  14.205128  3574.538462   32.92  2.508333
# 40   0.0  ...  14.0   7.0  7.666667  13.948718  3460.130178   32.80  2.166667
# 41   3.4  ...  12.6   6.3  7.333333  14.087179  3625.117160   33.28  2.091667
#
#       Zone 3  Zone 4  Indoor Average
# 37  7.866667     0.0       15.944444
# 38  7.800000     0.0       15.666667
# 39  7.733333     0.0       15.388889
# 40  7.666667     0.0       15.111111
# 41  7.333333     0.0       15.261111
#
# [5 rows x 22 columns]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
OR16UB_r = OR16UB.drop(range(37,117))
t0 = 80
time = OR16UB_r['Time'] - t0

plt.semilogy(time, OR16UB_r['Indoor Average']/(100*80), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 16 Unblocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.001, 1])

log_y_data = np.log(OR16UB_r['Indoor Average']/(100*80))

time = OR16UB['Time'][0:220]
y_data = log_y_data[0:220]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.002, color='black', linestyle='--', linewidth=5.0)

text = ('ln(DR) =' + t_text + 't' + ' + ' +  'ln(' + yd_text + ')')

plt.text(70, 0.06, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.02299087 -2.03425288]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR16UB['Time'], OR16UB['Indoor Average']/(100*80), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 16 Unblocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.001, 1])

log_y_data = np.log(OR16UB['Indoor Average']/(100*80))

time = OR16UB['Time'][80:300]
y_data = log_y_data[80:300]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.002, color='black', linestyle='--', linewidth=5.0)
plt.axhline(y=0.13, color='black', linestyle='--', linewidth=2.0)

text = ('ln(DR) = -0.0229(t - t0) + ln(0.13)')

plt.text(140, 0.07, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.02299087 -0.19498329]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR16B1['Time'], OR16B1['Zone 1']/(100*100), linewidth=5.0)
plt.semilogy(OR16B1['Time'], OR16B1['Zone 2']/(100*100), linewidth=5.0)
plt.semilogy(OR16B1['Time'], OR16B1['Zone 3']/(100*100), linewidth=5.0)
plt.title('OR 16 Blocked').set_size(30)
plt.xlabel('Time (s)').set_size(30)
plt.ylabel('Particle Concentration').set_size(30)
axes = plt.gca()
plt.ylim([0.0003, 1.1])
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.axhline(y=0.0015, color='black', linestyle='--', linewidth=5.0)
plt.legend(['Zone 1', 'Zone 2', 'Zone 3', 'Background'], prop = {'size':20})

# # Compute the area using the composite Simpson's rule.
# Zone_1 = simps(HMC1['Zone 1']/(100*110) - 0.0065, dx=0.01)
# #print("area 1 =", area_1)

# Zone_2 = simps(HMC1['Zone 2']/(100*110) - 0.0065, dx=0.01)
# #print("area 2 =", area_2)

# Zone_3 = simps(HMC1['Zone 3']/(100*110) - 0.0065, dx=0.01)
# #print("area 3 =", area_3)




# inside = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14'])/(100*110))/13 - 0.0065, dx=0.01)
# #print("Inside =", inside)

# door_sensors = simps(((DO1_Alt['S-15']+DO1_Alt['S-18']+DO1_Alt['S-19'])/3)/(100*110) - 0.0065, dx=0.01)
# #print("Door Sensors =", door_sensors)

# nurses_station = simps(DO1_Alt['S-16']/(100*110) - 0.0065, dx=0.01)
# #print("Nurse's Station =", nurses_station)

# total_average = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14']+DO1_Alt['S-15']+DO1_Alt['S-16']+DO1_Alt['S-18']+DO1_Alt['S-19'])/(100*110))/17 - 0.0065, dx=0.01)
# #print("Total Average =", total_average)

# print("Inside =", inside/total_average)
# print("Door Sensors =", door_sensors/total_average)
# print("Nurse's Station =", nurses_station/total_average)
# print("Outside =", Zone_3/total_average)
OR16B1.head()
# Out:
#     Time      S-01      S-03  S-04  S-05  S-06  S-07  S-08  S-09  S-11  ...  \
# 50     0  0.000000  7.333333   0.0   6.0   0.0  12.0   0.0   7.0   0.0  ...
# 51     1  0.133333  6.900000   0.0   6.0   0.0  12.0   0.0   6.3   0.3  ...
# 52     2  0.266667  6.466667   0.0   6.0   0.0  12.0   0.0   5.6   0.6  ...
# 53     3  0.400000  6.033333   0.0   6.0   0.0  12.0   0.0   4.9   0.9  ...
# 54     4  0.533333  5.600000   0.0   6.0   0.0  12.0   0.0   4.2   1.2  ...
#
#     S-14  S-15  S-BU1   Average   Variance  Zone 1    Zone 2  Zone 3  Zone 4  \
# 50  15.0   3.0    0.0  4.641026  61.526627     6.4  3.541667     0.0     0.0
# 51  14.4   2.7    0.0  4.517949  60.751479     6.2  3.466667     0.0     0.0
# 52  13.8   2.4    0.0  4.394872  59.976331     6.0  3.391667     0.0     0.0
# 53  13.2   2.1    0.0  4.271795  59.201183     5.8  3.316667     0.0     0.0
# 54  12.6   1.8    0.0  4.148718  58.426036     5.6  3.241667     0.0     0.0
#
#     Indoor Average
# 50        5.027778
# 51        4.894444
# 52        4.761111
# 53        4.627778
# 54        4.494444
#
# [5 rows x 22 columns]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
OR16B1_r = OR16B1.drop(range(50,160))
t0 = 110
time = OR16B1_r['Time'] - t0

plt.semilogy(time, OR16B1_r['Indoor Average']/(100*100), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 16 Blocked 1').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.001, 1])

log_y_data = np.log(OR16B1_r['Indoor Average']/(100*100))

time = OR16B1['Time'][0:150]
y_data = log_y_data[0:150]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.002, color='black', linestyle='--', linewidth=5.0)

text = ('ln(DR) =' + t_text + 't' + ' + ' +  'ln(' + yd_text + ')')

plt.text(45, 0.02, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.0188915 -3.4996702]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR16B1['Time'], OR16B1['Indoor Average']/(100*100), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 16 Blocked').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.001, 1])

log_y_data = np.log(OR16B1['Indoor Average']/(100*100))

time = OR16B1['Time'][110:260]
y_data = log_y_data[110:260]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.002, color='black', linestyle='--', linewidth=5.0)
plt.axhline(y=0.03, color='black', linestyle='--', linewidth=2.0)

text = ('ln(DR) = -0.0188(t - t0) + ln(0.03)')

plt.text(130, 0.04, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.0188915  -1.42160543]

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR16B2['Time'], OR16B2['Zone 1']/(100*80), linewidth=5.0)
plt.semilogy(OR16B2['Time'], OR16B2['Zone 2']/(100*80), linewidth=5.0)
plt.semilogy(OR16B2['Time'], OR16B2['Zone 3']/(100*80), linewidth=5.0)
plt.title('OR 16 Blocked 2').set_size(30)
plt.xlabel('Time (s)').set_size(30)
plt.ylabel('Particle Concentration').set_size(30)
axes = plt.gca()
plt.ylim([0.0003, 1.1])
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.axhline(y=0.0015, color='black', linestyle='--', linewidth=5.0)
plt.legend(['Zone 1', 'Zone 2', 'Zone 3', 'Background'], prop = {'size':20})

# # Compute the area using the composite Simpson's rule.
# Zone_1 = simps(HMC1['Zone 1']/(100*110) - 0.0065, dx=0.01)
# #print("area 1 =", area_1)

# Zone_2 = simps(HMC1['Zone 2']/(100*110) - 0.0065, dx=0.01)
# #print("area 2 =", area_2)

# Zone_3 = simps(HMC1['Zone 3']/(100*110) - 0.0065, dx=0.01)
# #print("area 3 =", area_3)




# inside = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14'])/(100*110))/13 - 0.0065, dx=0.01)
# #print("Inside =", inside)

# door_sensors = simps(((DO1_Alt['S-15']+DO1_Alt['S-18']+DO1_Alt['S-19'])/3)/(100*110) - 0.0065, dx=0.01)
# #print("Door Sensors =", door_sensors)

# nurses_station = simps(DO1_Alt['S-16']/(100*110) - 0.0065, dx=0.01)
# #print("Nurse's Station =", nurses_station)

# total_average = simps(((DO1_Alt['S-01']+DO1_Alt['S-02']+DO1_Alt['S-03']+DO1_Alt['S-04']+DO1_Alt['S-05']+DO1_Alt['S-06']+DO1_Alt['S-07']+DO1_Alt['S-08']+DO1_Alt['S-09']+DO1_Alt['S-10']+DO1_Alt['S-12']+DO1_Alt['S-13']+DO1_Alt['S-14']+DO1_Alt['S-15']+DO1_Alt['S-16']+DO1_Alt['S-18']+DO1_Alt['S-19'])/(100*110))/17 - 0.0065, dx=0.01)
# #print("Total Average =", total_average)

# print("Inside =", inside/total_average)
# print("Door Sensors =", door_sensors/total_average)
# print("Nurse's Station =", nurses_station/total_average)
# print("Outside =", Zone_3/total_average)

# %%
fig = plt.figure(1, figsize=(12,8), dpi=64)
plt.semilogy(OR16B2['Time'], OR16B2['Indoor Average']/(100*80), linewidth = 5, color='gray', linestyle = '-')
plt.title('OR 16 Blocked 2').set_size(25)
plt.xlabel('Time (s)').set_size(25)
plt.ylabel('Normalized Particle Concentration').set_size(25)
axes = plt.gca()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylim([0.001, 1])

log_y_data = np.log(OR16B2['Indoor Average']/(100*80))

time = OR16B2['Time'][110:280]
y_data = log_y_data[110:280]

curve_fit = np.polyfit(time, y_data, 1)
print(curve_fit)
(t,yd) = (curve_fit)
t_text = str(truncate(t,4))
yd_text = str(truncate(math.exp(yd),3))


y = np.exp(curve_fit[1]) * np.exp(curve_fit[0]*time)
plt.plot(time, y, linewidth=4.0, color='black', linestyle='dashdot')
plt.axhline(y=0.0015, color='black', linestyle='--', linewidth=5.0)

text = ('ln(DR) =' + t_text + 't' + ' + ' +  'ln(' + yd_text + ')')

plt.text(180, 0.085, text, fontsize = 20)

plt.legend(['Average of Zones 1 & 2', 'Decay Rate', 'Background'], prop = {'size':20})
# Out:
# [-0.01868915 -1.21001431]
